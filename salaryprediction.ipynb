# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('C:/Users/HP 840 G3/Downloads/archive (3)/Copy of survey_results_public.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
df = df[["Country","EdLevel","YearsCodePro","Employment","ConvertedComp"]]
df = df.rename({"ConvertedComp":"Salary"}, axis=1)
df.head()
# Out:
#                   Country                                            EdLevel  \
# 0          United Kingdom                          Primary/elementary school
# 1  Bosnia and Herzegovina  Secondary school (e.g. American high school, G...
# 2                Thailand           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3           United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                 Ukraine           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#        YearsCodePro                              Employment   Salary
# 0               NaN  Not employed, and not looking for work      NaN
# 1               NaN      Not employed, but looking for work      NaN
# 2                 1                      Employed full-time   8820.0
# 3  Less than 1 year                      Employed full-time  61000.0
# 4                 9                      Employed full-time      NaN

# %%
df = df[df["Salary"].notnull()]
df.head()
# Out:
#          Country                                            EdLevel  \
# 2       Thailand           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3  United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5         Canada           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8    New Zealand  Some college/university study without earning ...
# 9          India        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#        YearsCodePro          Employment    Salary
# 2                 1  Employed full-time    8820.0
# 3  Less than 1 year  Employed full-time   61000.0
# 5                 3  Employed full-time  366420.0
# 8                 4  Employed full-time   95179.0
# 9                10  Employed full-time   13293.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55823 entries, 2 to 88330
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       55823 non-null  object
#  1   EdLevel       54992 non-null  object
#  2   YearsCodePro  55657 non-null  object
#  3   Employment    55685 non-null  object
#  4   Salary        55823 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 2.6+ MB

# %%
df = df.dropna()
df.isna().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCodePro    0
# Employment      0
# Salary          0
# dtype: int64

# %%
df = df[df["Employment"]== "Employed full-time"]
df = df.drop("Employment", axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48248 entries, 2 to 88330
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       48248 non-null  object
#  1   EdLevel       48248 non-null  object
#  2   YearsCodePro  48248 non-null  object
#  3   Salary        48248 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.8+ MB

# %%
df
# Out:
#              Country                                            EdLevel  \
# 2           Thailand           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3      United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5             Canada           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8        New Zealand  Some college/university study without earning ...
# 9              India        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...              ...                                                ...
# 88325  United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88326        Finland        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88328        Austria        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88329    Netherlands        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88330         Greece           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#            YearsCodePro    Salary
# 2                     1    8820.0
# 3      Less than 1 year   61000.0
# 5                     3  366420.0
# 8                     4   95179.0
# 9                    10   13293.0
# ...                 ...       ...
# 88325                 3  130000.0
# 88326                 7   82488.0
# 88328                 9   68745.0
# 88329                 8  588012.0
# 88330                 5   22915.0
#
# [48248 rows x 4 columns]

# %%
df['Country'].value_counts()
# Out:
# Country
# United States        13878
# India                 3635
# United Kingdom        3555
# Germany               3075
# Canada                1943
#                      ...
# Togo                     1
# Timor-Leste              1
# Brunei Darussalam        1
# Liechtenstein            1
# Andorra                  1
# Name: count, Length: 156, dtype: int64

# %% [markdown]
# getting rid of the countries with 1

# %%
def shorten_categories(categories, cutoff):
    categorical_map = {}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            categorical_map[categories.index[i]]= categories.index[i]
        else:
            categorical_map[categories.index[i]] = 'other'
    return categorical_map

# %%
country_map = shorten_categories(df.Country.value_counts(), 400)
df['Country'] = df['Country'].map(country_map)
df.Country.value_counts()
# Out:
# Country
# United States         13878
# other                 10698
# India                  3635
# United Kingdom         3555
# Germany                3075
# Canada                 1943
# France                 1435
# Brazil                 1178
# Australia              1079
# Spain                  1058
# Poland                  983
# Russian Federation      946
# Netherlands             940
# Sweden                  804
# Italy                   795
# Israel                  496
# Switzerland             478
# Turkey                  433
# Ukraine                 430
# Belgium                 409
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary','Country', ax=ax)
plt.title('Salary (US$) v Country')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df= df[df['Salary'] <= 250000]
df= df[df['Salary'] >= 10000]
df= df[df['Country'] != 'other']

# %%
fig, ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary','Country', ax=ax)
plt.title('Salary (US$) v Country')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df['YearsCodePro'].unique()
# Out:
# array(['Less than 1 year', '10', '8', '2', '3', '13', '18', '1', '14',
#        '23', '19', '35', '20', '9', '25', '7', '5', '27', '6', '48', '4',
#        '31', '11', '12', '17', '16', '15', '29', '26', '30', '33', '21',
#        '37', '28', '22', '40', '34', '24', '32', '38', '44', '36', '43',
#        '41', '42', '39', '45', '47', 'More than 50 years', '50', '49'],
#       dtype=object)

# %%
def clean_experience(x):
    if x == 'More than 50 years':
        return 50
    if x == 'Less than 1 year':
        return 0.5
    return float(x)

df['YearsCodePro'] = df['YearsCodePro'].apply(clean_experience)

# %%
df['EdLevel']
# Out:
# 3                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9              Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 12             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13               Other doctoral degree (Ph.D, Ed.D., etc.)
# 16                Bachelor’s degree (BA, BS, B.Eng., etc.)
#                                ...
# 88309    Secondary school (e.g. American high school, G...
# 88312             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88318             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88323             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88325             Bachelor’s degree (BA, BS, B.Eng., etc.)
# Name: EdLevel, Length: 31731, dtype: object

# %%
df['EdLevel'].unique()
# Out:
# array(['Bachelor’s degree (BA, BS, B.Eng., etc.)',
#        'Master’s degree (MA, MS, M.Eng., MBA, etc.)',
#        'Other doctoral degree (Ph.D, Ed.D., etc.)',
#        'Some college/university study without earning a degree',
#        'Primary/elementary school',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Associate degree', 'Professional degree (JD, MD, etc.)',
#        'I never completed any formal education'], dtype=object)

# %%
def clean_education(x):
    # Convert to lowercase
    x = x.replace("Master's degree (MA, MS, M.Eng., MBA, etc.)", "Masters degree")
    x = x.replace("Bachelor's degree (BA, BS, B.Eng., etc.)", "Bachelors degree")
    x= str(x)
    
    if "Bachelors degree" in x:
        return "Bachelors degree"
    elif "Masters degree" in x:
        return "Masters degree"
    elif "Professional degree (JD, MD, etc.)" in x or 'Other doctoral degree (Ph.D, Ed.D., etc.)' in x:
        return "Post grad"
    else:
        return "Less than a Bachelors"
        
    # If none of the conditions match, return the original value
    

df['EdLevel'] = df['EdLevel'].apply(clean_education)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 19
#      14         return "Less than a Bachelors"
#      16     # If none of the conditions match, return the original value
# ---> 19 df['EdLevel'] = df['EdLevel'].apply(clean_education)
#      20 df['EdLevel']
#
# File c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[49], line 3, in clean_education(x)
#       1 def clean_education(x):
#       2     # Convert to lowercase
# ----> 3     x = x.replace("Master’s degree (MA, MS, M.Eng., MBA, etc.)", "Masters degree")
#       4     x = x.replace("Bachelor’s degree (BA, BS, B.Eng., etc.)", "Bachelors degree")
#       5     x= str(x)
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
df.head()
# Out:
#           Country           EdLevel  YearsCodePro   Salary
# 3   United States  Bachelors degree           0.5  61000.0
# 9           India    Masters degree          10.0  13293.0
# 12  United States    Masters degree           8.0  90000.0
# 13        Germany         Post grad           2.0  57060.0
# 16      Australia  Bachelors degree           2.0  65277.0

# %%
df.tail()
# Out:
#              Country                EdLevel  YearsCodePro    Salary
# 88309        Germany  Less than a Bachelors          17.0   97389.0
# 88312  United States       Bachelors degree          11.0  120000.0
# 88318         Poland       Bachelors degree           2.0   16032.0
# 88323  United States       Bachelors degree           2.0  180000.0
# 88325  United States       Bachelors degree           3.0  130000.0

# %%
df['EdLevel'].unique()
#the function above aint working as expexted
# Out:
# array(['Bachelors degree', 'Masters degree', 'Post grad',
#        'Less than a Bachelors'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le_education = LabelEncoder()
df['EdLevel'] = le_education.fit_transform(df['EdLevel'])
df['EdLevel'].unique()
# Out:
# array([0, 2, 3, 1])

# %%
df.head()
# Out:
#           Country  EdLevel  YearsCodePro   Salary
# 3   United States        0           0.5  61000.0
# 9           India        2          10.0  13293.0
# 12  United States        2           8.0  90000.0
# 13        Germany        3           2.0  57060.0
# 16      Australia        0           2.0  65277.0

# %%
le_country = LabelEncoder()
df['Country'] = le_country.fit_transform(df['Country'])
df['Country'].unique()
# Out:
# array([18,  6,  5,  0, 11,  2,  7, 14, 12, 10,  4,  9, 17,  3, 13,  8, 15,
#        16,  1])

# %%
X = df.drop("Salary", axis =1)
y = df["Salary"]

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X, y.values)
y_pred = linear_reg.predict(X)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
error = np.sqrt(mean_squared_error(y, y_pred))

# %%
error
# Out:
# 39435.03273441779

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree_reg = DecisionTreeRegressor(random_state=0)
dec_tree_reg.fit(X, y.values)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dec_tree_reg.predict(X)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
#error
# Out:
# $30,737.90

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_reg = RandomForestRegressor(random_state= 0)
random_forest_reg.fit(X, y.values)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = random_forest_reg.predict(X)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $30,785.10

# %%
from sklearn.model_selection import GridSearchCV

max_depth = [None, 2,4,6,8,10,12]
parameters = {"max_depth": max_depth}

regressor = DecisionTreeRegressor(random_state=0)
gs = GridSearchCV(regressor, parameters, scoring='neg_mean_squared_error')
gs.fit(X, y.values)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=0),
#              param_grid={'max_depth': [None, 2, 4, 6, 8, 10, 12]},
#              scoring='neg_mean_squared_error')

# %%
regressor = gs.best_estimator_

regressor.fit(X, y.values)
y_pred = regressor.predict(X)
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $31,121.22

# %%
X
# Out:
#        Country  EdLevel  YearsCodePro
# 3           18        0           0.5
# 9            6        2          10.0
# 12          18        2           8.0
# 13           5        3           2.0
# 16           0        0           2.0
# ...        ...      ...           ...
# 88309        5        1          17.0
# 88312       18        0          11.0
# 88318       10        0           2.0
# 88323       18        0           2.0
# 88325       18        0           3.0
#
# [31731 rows x 3 columns]

# %%
X = np.array([["United States", 'Masters degree',15]])
X
# Out:
# array([['United States', 'Masters degree', '15']], dtype='<U14')

# %%
X[:, 0] = le_country.transform(X[:,0])
X[:, 1] = le_education.transform(X[:,1])
X = X.astype(float)
X
# Out:
# array([[18.,  2., 15.]])

# %%
y_pred = regressor.predict(X)
y_pred
# Out:
# c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([139056.10465116])

# %%
import joblib

# %%
data = {"model": regressor, "le_country": le_country, "le_education":le_education}

# %%
from joblib import dump
dump(data, 'saved_steps.joblib')
# Out:
# ['saved_steps.joblib']

# %%
from joblib import load

data = load('saved_steps.joblib')
regressor_loaded = data['model']
print(data)
# Out:
# {'model': DecisionTreeRegressor(max_depth=12, random_state=0), 'le_country': LabelEncoder(), 'le_education': LabelEncoder()}

# %%
y_pred = regressor_loaded.predict(X)
y_pred
# Out:
# c:\Users\HP 840 G3\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([139056.10465116])
